# %%
# !pip install -q -U "google-generativeai>=0.7.2"

# %%
import google.generativeai as genai

# %%
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key = GOOGLE_API_KEY)

# %%
# Function to automatically select an available Gemini model
def get_available_gemini_model():
    models_to_try = [
        "gemini-1.5-flash" ,
        "gemini-1.5-flash-8b",  # Try 8B model first
        "gemini-1.5-flash-002"   # Fall back to standard flash model
    ]

    for model_name in models_to_try:
        try:
            model = genai.GenerativeModel(model_name=model_name)
            # If model initializes without error, return it
            print(f"Using model: {model_name}")
            return model
        except Exception as e:
            print(f"Model {model_name} is unavailable. Trying next...")

    raise RuntimeError("No available Gemini models found. Please check API access.")

# Initialize the model
model = get_available_gemini_model()
# Out:
# Using model: gemini-1.5-flash

# %%
# Extra code to visualize the img
import PIL.Image
image1 = "amazon-home.png"
image2 = "amazon-search.png"
image3= "product-detail.png"
image4 = "add-to-cart.png"
image5= "confirmation.png"

img1 = PIL.Image.open(image1)
img2 = PIL.Image.open(image2)
img3 = PIL.Image.open(image3)
img4 = PIL.Image.open(image4)
img5 = PIL.Image.open(image5)

# %%
# Fucntion to generate descriptions for above images based on the prompt
import google.generativeai as genai
from PIL import Image

def describe_img(image_path):
     """ Generate description of the image using gemini"""
     try:
        # Open the image
        img = Image.open(image_path)
        # Write the prompt for that image
        prompt =""" This image contains home screen of an app. Given the screenshot describe the site in as much detail as possible
            making sure you note all the items on the screen. Return output in json format : {description:description , items:[item1 ,
            item2 , item3 , etc]}"""
        # Write the response
        response = model.generate_content([prompt, img])
        description = response.text
        return description if description else "No description generated"
     except Exception as e:
        return f"Error:{e}"

image_paths =[
    "amazon-home.png",
    "amazon-search.png",
    "product-detail.png",
    "add-to-cart.png",
    "confirmation.png"]

image_descriptions = [describe_img(img) for img in image_paths]

for i, desc in enumerate(image_descriptions,1):
    print(f"Image {i}: {desc}")
# Out:
# Image 1: ```json
# {
#   "description": "This is a screenshot of the Amazon.com homepage. The top navigation bar displays options for searching, account management, returns, and the shopping cart. The main section showcases a banner for \"Shop Books\", followed by sections featuring \"Pick up where you left off\" (showing scarves), \"Shop for your home essentials\" (showing cleaning tools and storage), \"Get your game on\" (showing a computer), and \"Top categories in Kitchen appliances\" (showing a pressure cooker).  The location is set to Pune, India. A message indicates that the user is currently on the .com site, with an option to switch to the .in site for local delivery.",
#   "items": [
#     {"type": "navigation", "item": "All"},
#     {"type": "navigation", "item": "Rufus"},
#     {"type": "navigation", "item": "Today's Deals"},
#     {"type": "navigation", "item": "Buy Again"},
#     {"type": "navigation", "item": "Customer Service"},
#     {"type": "navigation", "item": "Registry"},
#     {"type": "navigation", "item": "Gift Cards"},
#     {"type": "navigation", "item": "Sell"},
#     {"type": "search bar", "item": "Search Amazon"},
#     {"type": "location", "item": "Deliver to Sanskruti, Pune 411005"},
#     {"type": "banner", "item": "Shop Books, explore titles"},
#     {"type": "section", "item": "Pick up where you left off (scarves)"},
#     {"type": "section", "item": "Shop for your home essentials (cleaning tools and storage)"},
#     {"type": "section", "item": "Get your game on (computer)"},
#     {"type": "section", "item": "Top categories in Kitchen appliances (pressure cooker)"},
#     {"type": "message", "item": "You are on amazon.com. You can also shop on Amazon India for millions of products with fast local delivery. Click here to go to amazon.in"},
#     {"type": "account", "item": "Hello, Sanskruti"},
#     {"type": "account", "item": "Account & Lists"},
#     {"type": "account", "item": "Returns & Orders"},
#     {"type": "account", "item": "Cart (1 item)"},
#     {"type": "language", "item": "EN"}
#   ]
# }
# ```
# Image 2: ```json
# {
#   "description": "This is a screenshot of the Amazon India homepage. The search bar is active, showing search suggestions related to \"laptop\". The top navigation bar includes options for All, Today's Deals, Buy Again, Account & Lists, Returns, and Orders.  The user's location is set to Pune 411005. The main body of the page features several sections, including \"Pick up where you left off\" (showing recently viewed laptops), \"Shop for your home essentials\" (showing cleaning tools and home storage items), \"Get your game on\" (showing gaming PCs), and \"Top categories in Kitchen appliances\" (showing a pressure cooker).  The language is set to English.",
#   "items": [
#     "Amazon logo",
#     "Deliver to Sanskruti",
#     "Location: Pune 411005",
#     "All (dropdown)",
#     "Search bar: 'laptop'",
#     "Search suggestions: 'laptop stand', 'laptop touchscreen', 'laptop dell', 'laptop touch screen', 'laptop charger', 'laptop bag', 'laptop lenovo', 'hp laptop', 'laptops on sale', 'laptop 16'",
#     "All (category)",
#     "Rufus (logo/link)",
#     "Today's Deals",
#     "Buy Again",
#     "Hello, Sanskruti",
#     "Account & Lists (dropdown)",
#     "Returns",
#     "Orders",
#     "Shopping cart (3 items)",
#     "Left navigation arrow",
#     "Right navigation arrow",
#     "Pick up where you left off",
#     "Lenovo V15 Business Laptop",
#     "HP 14 Laptop, Intel Evo Platform",
#     "Shop for your home essentials",
#     "Cleaning Tools",
#     "Home Storage",
#     "Get your game on",
#     "(image of a gaming PC)",
#     "Top categories in Kitchen appliances",
#     "(image of a pressure cooker)"
#   ]
# }
# ```
# Image 3: ```json
# {
#   "description": "This is an Amazon product page for a JOYEKY laptop stand. The stand is grey, foldable, and portable, with a 360-degree rotating base. It's designed for laptops between 10 and 16 inches. The page includes multiple images of the product from different angles, customer ratings (4.7 stars),  pricing information (various options with different prices), and options to see similar items, view all buying options, and add the product to a list.  The page also shows the product's specifications, including brand, color, form factor, compatible devices, and compatible phone models.",
#   "items": [
#     "Amazon logo",
#     "Search bar with 'laptop stand' entered",
#     "Delivery location: Sankruti, Pune 411005",
#     "Navigation menu: All, Rufus, Today's Deals, Buy Again, Customer Service, Registry, Gift Cards, Sell",
#     "Back to results link",
#     "Multiple product images (thumbnails)",
#     "11 Videos indicator",
#     "360° view indicator",
#     "Main product image showcasing the laptop stand with a laptop on it",
#     "Product title: Laptop Stand for Desk, Adjustable Computer Stand with 360° Rotating Base, Ergonomic Laptop Riser for Collaborative Work, Foldable & Portable Laptop Stand, fits for All 10-16\" Laptops",
#     "Visit the JOYEKY Store link",
#     "Star rating: 4.7 out of 5 stars (1,919 ratings)",
#     "Amazon's Choice badge",
#     "Search this page link",
#     "No featured offers available message",
#     "Learn more link",
#     "Deliver to Sankruti - Pune 411005 information",
#     "See Similar Items button",
#     "See All Buying Options button",
#     "Add to List button",
#     "Color option: Grey",
#     "Multiple product images (showing different views/angles)",
#     "Pricing information (INR prices and number of options available for each)",
#     "Brand: JOYEKY",
#     "Color: Grey",
#     "Form Factor: Tower",
#     "Compatible Devices: Laptops",
#     "Compatible Phone Models: MacBook 12 inch/13 inch, MacBook Air 13 inch, MacBook Pro 13 inch / 14inch/ 16 inch, Dell XPS HP Lenovo Acer Chromebook and more All 10-16 inches...",
#     "See more link (for compatible phone models)",
#     "Roll over image to zoom in instruction"
#   ]
# }
# ```
# Image 4: ```json
# {
#   "description": "This is an Amazon product page for a JOYEKY Laptop Stand for Desk. The stand is adjustable and has a 360° rotating base. It is compatible with various laptops, including MacBook 12/13 inch, MacBook Pro 13/14 inch, and Lenovo Acer Chromebooks. The product page shows the laptop stand with a laptop on it, multiple color options, customer reviews, and seller information.  A message indicates that the item cannot be shipped to the selected delivery location.",
#   "items": [
#     "Amazon logo and search bar",
#     "Delivery location (Pune 411005)",
#     "Search term (laptop+stand)",
#     "Navigation menu (All, Today's Deals, Buy Again, Customer Service, Registry, Gift Cards, Sell)",
#     "Back to results link",
#     "Product image carousel (multiple views of the laptop stand)",
#     "360° view icon",
#     "11 videos icon",
#     "Product title (Laptop Stand for Desk, Adjustable Stand with 360° Rotating Base, Laptop Riser for Collaborative & Portable Laptop Stand, fits Laptops)",
#     "Visit the JOYEKY Store link",
#     "Product rating (4.7 stars)",
#     "Amazon's Choice badge",
#     "Number of reviews (1,919)",
#     "Search this page link",
#     "Color selection (Grey)",
#     "Multiple images showing different angles of the laptop stand in grey color",
#     "Price (INR 3,114.25)",
#     "Number of options (1,1,1,2)",
#     "Brand (JOYEKY)",
#     "Color (Grey)",
#     "Form Factor (Tower)",
#     "Compatible Devices (Laptops)",
#     "Compatible Phone Models (MacBook 12 inch/ 13 inch, MacBook Pro 13 inch / 14 inch, Lenovo Acer Chromebook and others)",
#     "See more link",
#     "Product image (laptop stand with laptop)",
#     "Rating (★★★★★)",
#     "Number of ratings (1,919)",
#     "Message indicating the item cannot be shipped to the selected location",
#     "Coupon option",
#     "Add to Cart button",
#     "Ships from (Amazon.com)",
#     "Sold by (Jiexunke Electronic)",
#     "Seller rating (★★★★★)",
#     "Number of seller ratings (1038)",
#     "Positive feedback percentage (95%)",
#     "Customer service link",
#     "Alternative product suggestions (two similar laptop stands)",
#     "Pagination (Page 1 of 5)",
#     "Previous and next page buttons"
#   ]
# }
# ```
# Image 5: ```json
# {
#   "description": "This is a screenshot of the Amazon website's home screen.  The screen shows a recently added item to the cart, a TPV laptop, and product recommendations based on the user's shopping trends.  The cart subtotal is displayed, along with options to proceed to checkout or view the cart.  Several laptops are presented as recommended items, with various specifications listed such as processor, RAM, storage, and display size. Customer reviews and star ratings are shown for each laptop. The page also shows a section for other items in the cart.",
#   "items": [
#     {
#       "name": "Added to Cart Item",
#       "description": "TPV Laptop Computer, 15.6\" FHD Display, 16GB RAM, 512GB SSD, MS Office...",
#       "price": "$309.99",
#       "rating": "4.3 stars (72 reviews)",
#       "image": "Image of a grey laptop on a stand"
#     },
#     {
#       "name": "Cart Subtotal",
#       "description": "$1,178.05",
#       "items_in_cart": "6 items"
#     },
#     {
#       "name": "Recommended Laptops",
#       "description": "A selection of Lenovo and Dell laptops with varying specs (size, RAM, processor, storage etc.) and customer ratings"
#     },
#     {
#       "name": "Other Cart Items",
#       "description": "Displaying two additional items in the user's cart including a laptop stand and a book titled \"Hands-On Machine Learning with Scikit-Learn, Keras & TensorFlow\""
#     },
#     {
#       "name": "Navigation Bar",
#       "description": "Includes options like 'All', 'Today's Deals', 'Buy Again', 'Gift Cards', 'Sanskruti's Amazon.com', 'Sell', 'Customer Service', 'Browsing History', and 'Registry'"
#     },
#     {
#       "name": "Account Information",
#       "description": "Displays the user's location (Pune 411005), language (EN), and account details (Hello, Sanskruti)."
#     }
#   ]
# }
# ```

# %%
# Use the above function to generate test-cases from the above decriptions:
import json
def generate_prompt_for_test_cases(descriptions):
    """ Generate detailed prompt for the Gemini api to create structured test cases for the given screenshots"""
    prompt =""" You are an AI test case generator. Based on the screenshots and their descriptions
            generate 3 meaningful test cases for each screenshot. The test cases should be structured
            to verify user interactions, UI elements and expected system behaviour.\

            ### **Guidelines:**
            - The test cases should be a bit generic and applicable to any application.
            - Each test case should comtain **Title, Objective and Test Steps.**
            - The steps should include :
            - **Action** - The user interaction(e.g. "Click the 'Search' button" , "Open the Amazon.in website in a browser")
            - **Data(if applicable)**- Any input required(e.g. "Search term :'Laptop Stand'")
            - **Expected Result** - What should happen after the action(e.g. "The Amazon homepage is displayed with a search bar visible at the top.")


            ---
            ##**Example Format:**
            [{
              Test Case 1
              "Title" : "Search for a Product on Amazon.in" ,

              "Objective" : "To ensure the search functionality on Amazon.in returns relevant results when a user
              searches for a product.",

              "Test Steps":[
              {"Step 1":
              "Action": "Open the Amazon.in website in a browser.",
              "Data": "https://amazon.in",
              "Expected Result": "The Amazon homepage is displayed with a search bar visible at the top."},

              { "Step 2":
              "Action": "Enter the product name (e.g., 'laptop stand') in the search bar.",
              "Data" : "laptop stand",
              "Expected Result" : "The search bar displays the entered text ('laptop stand')." },

              {"Step 3":
              "Action": "Click on the “Search” icon or press “Enter” on the keyboard.",
              "Data": "None",
              "Expected Result": "The page refreshes, and the product search results related to 'laptop stand' are
              displayed."},

              {"Step 4":
              "Action": "Verify that the search results are relevant to the product searched.",
              "Data": "None",
              "Expected Result": "The page shows a list of laptops, including product names, images, prices,
              and other relevant information."}
              ]}]}]

            """
            # Add image descriptions to the prompt:
    for i,description in enumerate(image_descriptions):
        prompt += f"Image {i+1}: {description}\n"

    prompt += "Ensure each image has exactly 3 structured test cases.Ensure the test cases cover functional correctness, UI validation, and user interaction validation. Output must be strictly in JSON format."

    return prompt

model = genai.GenerativeModel('gemini-1.5-flash')
test_case_prompt = generate_prompt_for_test_cases(image_descriptions)
response = model.generate_content(test_case_prompt)
modified_response = response.text.replace("```json", "").replace("```", "")
print(modified_response)
# Out:
# [
#   {
#     "image": 1,
#     "testCases": [
#       {
#         "Title": "Verify Homepage Navigation and Elements",
#         "Objective": "To ensure all navigational elements on the Amazon.com homepage are functional and displayed correctly.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Open the Amazon.com website in a browser.",
#             "Data": "https://www.amazon.com",
#             "ExpectedResult": "The Amazon homepage loads successfully, displaying all expected elements (navigation bar, search bar, featured sections, etc.)."
#           },
#           {
#             "Step": 2,
#             "Action": "Click on each navigation item in the top navigation bar (All, Rufus, Today's Deals, etc.).",
#             "Data": "None",
#             "ExpectedResult": "Each navigation link should correctly redirect to the respective section or page.  Error messages should be absent."
#           },
#           {
#             "Step": 3,
#             "Action": "Verify the location and language settings displayed on the homepage.",
#             "Data": "Pune, India; EN",
#             "ExpectedResult": "The location and language are correctly displayed as Pune, India and English (EN), respectively.  A clear option to switch to amazon.in is present."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Search Functionality on Homepage",
#         "Objective": "To validate that the search bar on the Amazon.com homepage functions correctly.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Enter a search term in the search bar (e.g., 'laptop stand').",
#             "Data": "laptop stand",
#             "ExpectedResult": "The search term is displayed in the search bar."
#           },
#           {
#             "Step": 2,
#             "Action": "Click the search icon or press Enter.",
#             "Data": "None",
#             "ExpectedResult": "The search results page loads, displaying relevant results for the entered search term."
#           },
#           {
#             "Step": 3,
#             "Action": "Verify that the search results are relevant to the search term.",
#             "Data": "None",
#             "ExpectedResult": "The results page shows products related to 'laptop stand'."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Switching Between Amazon.com and Amazon.in",
#         "Objective": "To ensure the user can easily switch between the .com and .in websites.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Locate the message prompting to switch to amazon.in.",
#             "Data": "None",
#             "ExpectedResult": "The message is clearly visible and contains a clickable link to amazon.in."
#           },
#           {
#             "Step": 2,
#             "Action": "Click the link to switch to amazon.in.",
#             "Data": "None",
#             "ExpectedResult": "The webpage redirects to the Amazon.in homepage."
#           },
#           {
#             "Step": 3,
#             "Action": "Verify that the new page is the Amazon.in homepage and displays content specific to the Indian region.",
#             "Data": "None",
#             "ExpectedResult": "The Amazon.in homepage loads, displaying relevant content and currency (INR)."
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "image": 2,
#     "testCases": [
#       {
#         "Title": "Verify Search Suggestions",
#         "Objective": "To ensure that the search bar provides relevant suggestions.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Observe the search bar.",
#             "Data": "None",
#             "ExpectedResult": "The search bar displays the search term 'laptop' and relevant suggestions."
#           },
#           {
#             "Step": 2,
#             "Action": "Type additional characters in the search bar.",
#             "Data": "laptops",
#             "ExpectedResult": "The suggestions dynamically update based on the characters entered."
#           },
#           {
#             "Step": 3,
#             "Action": "Select a suggestion from the dropdown.",
#             "Data": "laptop stand",
#             "ExpectedResult": "The selected suggestion populates the search bar, and relevant search results are displayed."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Navigation and Account Access",
#         "Objective": "To test the functionality of the navigation bar and user account access.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Click on 'Account & Lists'.",
#             "Data": "None",
#             "ExpectedResult": "The user's account page or a dropdown menu with account options is displayed."
#           },
#           {
#             "Step": 2,
#             "Action": "Click on 'Returns'.",
#             "Data": "None",
#             "ExpectedResult": "The user is redirected to the returns page."
#           },
#           {
#             "Step": 3,
#             "Action": "Click on 'Orders'.",
#             "Data": "None",
#             "ExpectedResult": "The user is redirected to their order history page."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Homepage Section Display",
#         "Objective": "To check if all sections on the homepage are displayed correctly.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Verify the visibility of the sections: 'Pick up where you left off', 'Shop for your home essentials', 'Get your game on', and 'Top categories in Kitchen appliances'.",
#             "Data": "None",
#             "ExpectedResult": "All sections are displayed with appropriate titles and images."
#           },
#           {
#             "Step": 2,
#             "Action": "Click on a product within one of the sections.",
#             "Data": "Lenovo V15 Business Laptop",
#             "ExpectedResult": "The product page for the selected item loads successfully."
#           },
#           {
#             "Step": 3,
#             "Action": "Verify the correctness of the location displayed at the top of the homepage.",
#             "Data": "Pune 411005",
#             "ExpectedResult": "The location is correctly displayed as Pune 411005."
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "image": 3,
#     "testCases": [
#       {
#         "Title": "Verify Product Details Display",
#         "Objective": "To ensure all product details are correctly displayed on the product page.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Verify that the product title, images, and description are displayed correctly.",
#             "Data": "JOYEKY laptop stand",
#             "ExpectedResult": "The title, images, and description accurately reflect the product."
#           },
#           {
#             "Step": 2,
#             "Action": "Verify the pricing information, including the number of options and prices.",
#             "Data": "None",
#             "ExpectedResult": "The pricing information is clear, accurate, and consistent."
#           },
#           {
#             "Step": 3,
#             "Action": "Verify the customer ratings and reviews.",
#             "Data": "None",
#             "ExpectedResult": "The ratings and reviews section is displayed, showing the average rating and the number of reviews."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Product Page Functionality",
#         "Objective": "To test the functionality of buttons and links on the product page.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Click 'See Similar Items'.",
#             "Data": "None",
#             "ExpectedResult": "A page showing similar products is displayed."
#           },
#           {
#             "Step": 2,
#             "Action": "Click 'See All Buying Options'.",
#             "Data": "None",
#             "ExpectedResult": "A page displaying all available buying options for the product is displayed."
#           },
#           {
#             "Step": 3,
#             "Action": "Click 'Add to List'.",
#             "Data": "None",
#             "ExpectedResult": "A prompt or a new page appears allowing the user to add the item to a list, or an appropriate message if no lists exist."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Product Specifications",
#         "Objective": "To ensure the product specifications are displayed correctly and completely.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Verify that the brand, color, form factor, compatible devices, and compatible phone models are accurately displayed.",
#             "Data": "JOYEKY, Grey, Tower, Laptops, MacBook 12 inch/13 inch...",
#             "ExpectedResult": "All specifications are displayed correctly and match the product description."
#           },
#           {
#             "Step": 2,
#             "Action": "Verify that the 'See more' link for compatible phone models functions correctly.",
#             "Data": "None",
#             "ExpectedResult": "Clicking the link expands or shows a complete list of compatible phone models."
#           },
#           {
#             "Step": 3,
#             "Action": "Verify the zoom functionality of the product images.",
#             "Data": "None",
#             "ExpectedResult": "Hovering over or clicking on product images allows for zooming in for better viewing."
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "image": 4,
#     "testCases": [
#       {
#         "Title": "Verify Product Information and Availability",
#         "Objective": "To verify that product information and shipping restrictions are displayed correctly.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Verify that the product title, images, description, price, and specifications are displayed correctly.",
#             "Data": "JOYEKY Laptop Stand",
#             "ExpectedResult": "All information is accurate and matches the product."
#           },
#           {
#             "Step": 2,
#             "Action": "Verify the shipping message.",
#             "Data": "Item cannot be shipped to the selected location.",
#             "ExpectedResult": "A clear message indicates that the item cannot be shipped to the specified location (Pune 411005)."
#           },
#           {
#             "Step": 3,
#             "Action": "Verify seller information (name, rating, and feedback).",
#             "Data": "Jiexunke Electronic",
#             "ExpectedResult": "Seller information is clearly displayed, including name, rating, and feedback percentage."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Add to Cart Functionality",
#         "Objective": "To test the 'Add to Cart' button functionality.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Click the 'Add to Cart' button.",
#             "Data": "None",
#             "ExpectedResult": "A confirmation message is displayed or the cart is updated to reflect the addition of the item, considering shipping restrictions."
#           },
#           {
#             "Step": 2,
#             "Action": "Verify the cart contents after clicking 'Add to Cart'.",
#             "Data": "None",
#             "ExpectedResult": "The cart correctly displays the added item if it's added, or a message explaining why it cannot be added."
#           },
#           {
#             "Step": 3,
#             "Action": "Check the cart for the added item and proceed to checkout (if applicable).",
#             "Data": "None",
#             "ExpectedResult": "The checkout process should be initiated correctly, or a relevant message displayed if checkout is impossible."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Product Page Navigation",
#         "Objective": "To ensure proper navigation within the product page.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Click 'Back to results'.",
#             "Data": "None",
#             "ExpectedResult": "The user is redirected to the search results page from which the product was accessed."
#           },
#           {
#             "Step": 2,
#             "Action": "Click on the 'Visit the JOYEKY Store' link.",
#             "Data": "None",
#             "ExpectedResult": "The page redirects to the JOYEKY store page on Amazon."
#           },
#           {
#             "Step": 3,
#             "Action": "Navigate through the product image carousel using the navigation arrows.",
#             "Data": "None",
#             "ExpectedResult": "The carousel correctly displays all product images."
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "image": 5,
#     "testCases": [
#       {
#         "Title": "Verify Cart Information and Checkout",
#         "Objective": "To verify the cart information and checkout process.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Verify the recently added item in the cart (TPV laptop).",
#             "Data": "TPV Laptop Computer",
#             "ExpectedResult": "The laptop is correctly displayed with its price and other details."
#           },
#           {
#             "Step": 2,
#             "Action": "Verify the cart subtotal and the number of items in the cart.",
#             "Data": "$1,178.05, 6 items",
#             "ExpectedResult": "The subtotal and item count are accurate."
#           },
#           {
#             "Step": 3,
#             "Action": "Click 'Proceed to checkout' button.",
#             "Data": "None",
#             "ExpectedResult": "The user is redirected to the checkout page, or an appropriate error is displayed if there are issues with the checkout process."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Product Recommendations",
#         "Objective": "To verify that product recommendations are relevant and displayed correctly.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Observe the 'Recommended Laptops' section.",
#             "Data": "None",
#             "ExpectedResult": "The section displays a selection of laptops relevant to the user's past purchases or browsing history."
#           },
#           {
#             "Step": 2,
#             "Action": "Verify the specifications and ratings of the recommended laptops.",
#             "Data": "None",
#             "ExpectedResult": "Specifications (processor, RAM, etc.) and customer ratings are displayed for each laptop."
#           },
#           {
#             "Step": 3,
#             "Action": "Click on a recommended laptop.",
#             "Data": "Any recommended laptop",
#             "ExpectedResult": "The user is redirected to the product page of the selected laptop."
#           }
#         ]
#       },
#       {
#         "Title": "Verify Navigation and Account Information",
#         "Objective": "To test the navigation bar and account information display.",
#         "TestSteps": [
#           {
#             "Step": 1,
#             "Action": "Verify the presence and functionality of items in the navigation bar ('All', 'Today's Deals', etc.).",
#             "Data": "None",
#             "ExpectedResult": "All navigation links function correctly."
#           },
#           {
#             "Step": 2,
#             "Action": "Verify the user's location and language are displayed correctly.",
#             "Data": "Pune 411005, EN",
#             "ExpectedResult": "The location and language are correctly displayed."
#           },
#           {
#             "Step": 3,
#             "Action": "Verify that the user's account information ('Hello, Sanskruti') is displayed.",
#             "Data": "None",
#             "ExpectedResult": "The user's name is displayed in the account section."
#           }
#         ]
#       }
#     ]
#   }
# ]

# %%
# Convert the test-cases into a structured json response
# GENERATE STRUCTURED JSON
def generate_test_cases(image_paths):
    test_case_prompt = generate_prompt_for_test_cases(image_descriptions)
    model = genai.GenerativeModel('gemini-1.5-flash')
    response = model.generate_content(test_case_prompt)
    modified_response = response.text.replace("```json", "").replace("```", "")
  # Try parsing JSON
    try:
        test_cases = json.loads(modified_response)
    except json.JSONDecodeError:
        test_cases = {"error": "Failed to parse response as JSON."}

    return test_cases
test_cases_output = generate_test_cases(image_paths)
print(json.dumps(test_cases_output, indent=4))

# %%
def save_output(test_cases, filename="test_cases.json"):
    """Save the generated test cases to a JSON file."""
    try:
      with open(filename, "w" , encoding ="utf-8") as f:
          json.dump(test_cases, f, indent=4, ensure_ascii=False)
    except Exception as e:
        print(f"Error saving output to {filename}: {e}")

save_output(test_cases_output)

# %%
import json
from PIL import Image
import google.generativeai as genai

def get_ui_elements_coordinates(image_path):
    """Extract UI elements with their coordinates from a screenshot."""

    # Open the image
    img = Image.open(image_path)

    # Define prompt for Gemini model
    prompt = """Analyze the image screenshot and detect interactive UI elements like input fields,
                buttons, checkboxes, etc.
                For each detected element, return:
                - The name/label of the element if available.
                - The type of the element (button, text field, dropdown, etc.).
                - The bounding box coordinates in pixels as {"x": X, "y": Y, "width": W, "height": H}.
                Return the response in JSON format.
             """

    # Generate response using Gemini model
    response = model.generate_content([prompt, img])

    # Process response text
    modified_response = response.text.replace("```json", "").replace("```", "").strip()

    try:
        coordinates = json.loads(modified_response)  # Convert string to JSON
    except json.JSONDecodeError:
        coordinates = {"error": "Failed to parse response as JSON."}
        coordinates =[]

    return coordinates

# List of images
image_paths = [
    "amazon-home.png",
    "amazon-search.png",
    "product-detail.png",
    "add-to-cart.png",
    "confirmation.png"
]

# Get UI element coordinates for each image
ui_coordinates = {image: get_ui_elements_coordinates(image) for image in image_paths}

# Print results
for image, coordinates in ui_coordinates.items():
    print(f"Image: {image} -> UI Elements:{coordinates}")

# %%
for image , coordinates in ui_coordinates.items():
  save_output(coordinates , f"{image}_coordinates.json")

# %%
def save_ui_coordinates(ui_coordinates, filename="ui_coordinates.json"):
    """Save the generated test cases to a JSON file."""
    try:
      with open(filename, "w" , encoding ="utf-8") as f:
          json.dump(ui_coordinates, f, indent=4, ensure_ascii=False)
    except Exception as e:
        print(f"Error saving output to {filename}: {e}")

save_output(ui_coordinates)

# %%
with open("ui_coordinates.json", "w") as f:
    json.dump(ui_coordinates, f, indent=4)

# Print output
print(json.dumps(ui_coordinates, indent=4))
# Out:
# {
#     "amazon-home.png": [
#         {
#             "name": "Search Amazon",
#             "type": "text field",
#             "bounding_box": {
#                 "x": 267,
#                 "y": 78,
#                 "width": 180,
#                 "height": 28
#             }
#         },
#         {
#             "name": "All",
#             "type": "dropdown",
#             "bounding_box": {
#                 "x": 187,
#                 "y": 78,
#                 "width": 50,
#                 "height": 28
#             }
#         },
#         {
#             "name": "Go",
#             "type": "button",
#             "bounding_box": {
#                 "x": 456,
#                 "y": 78,
#                 "width": 28,
#                 "height": 28
#             }
#         },
#         {
#             "name": "Account & Lists",
#             "type": "dropdown",
#             "bounding_box": {
#                 "x": 746,
#                 "y": 78,
#                 "width": 130,
#                 "height": 28
#             }
#         },
#         {
#             "name": "Cart",
#             "type": "button",
#             "bounding_box": {
#                 "x": 915,
#                 "y": 78,
#                 "width": 50,
#                 "height": 28
#             }
#         },
#         {
#             "name": "Stop sharing",
#             "type": "button",
#             "bounding_box": {
#                 "x": 547,
#                 "y": 928,
#                 "width": 90,
#                 "height": 24
#             }
#         },
#         {
#             "name": "Hide",
#             "type": "button",
#             "bounding_box": {
#                 "x": 645,
#                 "y": 928,
#                 "width": 44,
#                 "height": 24
#             }
#         }
#     ],
#     "amazon-search.png": [
#         {
#             "name": "Search",
#             "type": "text field",
#             "bounding_box": {
#                 "x": 265,
#                 "y": 28,
#                 "width": 107,
#                 "height": 29
#             }
#         },
#         {
#             "name": "All",
#             "type": "dropdown",
#             "bounding_box": {
#                 "x": 168,
#                 "y": 28,
#                 "width": 40,
#                 "height": 29
#             }
#         },
#         {
#             "name": "Account & Lists",
#             "type": "dropdown",
#             "bounding_box": {
#                 "x": 750,
#                 "y": 30,
#                 "width": 120,
#                 "height": 29
#             }
#         },
#         {
#             "name": "laptop stand",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 72,
#                 "width": 120,
#                 "height": 18
#             }
#         },
#         {
#             "name": "laptop touchscreen",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 95,
#                 "width": 150,
#                 "height": 18
#             }
#         },
#         {
#             "name": "laptop dell",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 118,
#                 "width": 107,
#                 "height": 18
#             }
#         },
#         {
#             "name": "laptop touch screen",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 141,
#                 "width": 150,
#                 "height": 18
#             }
#         },
#         {
#             "name": "laptop charger",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 164,
#                 "width": 126,
#                 "height": 18
#             }
#         },
#         {
#             "name": "laptop bag",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 187,
#                 "width": 97,
#                 "height": 18
#             }
#         },
#         {
#             "name": "laptop lenovo",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 210,
#                 "width": 126,
#                 "height": 18
#             }
#         },
#         {
#             "name": "hp laptop",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 233,
#                 "width": 97,
#                 "height": 18
#             }
#         },
#         {
#             "name": "laptops on sale",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 256,
#                 "width": 126,
#                 "height": 18
#             }
#         },
#         {
#             "name": "laptop 16",
#             "type": "list item",
#             "bounding_box": {
#                 "x": 286,
#                 "y": 279,
#                 "width": 97,
#                 "height": 18
#             }
#         },
#         {
#             "name": "Search",
#             "type": "button",
#             "bounding_box": {
#                 "x": 224,
#                 "y": 28,
#                 "width": 29,
#                 "height": 29
#             }
#         },
#         {
#             "name": "Cart",
#             "type": "button",
#             "bounding_box": {
#                 "x": 949,
#                 "y": 28,
#                 "width": 29,
#                 "height": 29
#             }
#         },
#         {
#             "name": "Returns",
#             "type": "link",
#             "bounding_box": {
#                 "x": 881,
#                 "y": 30,
#                 "width": 60,
#                 "height": 25
#             }
#         }
#     ],
#     "product-detail.png": [
#         {
#             "name": "See Similar Items",
#             "type": "button",
#             "bbox": {
#                 "x": 840,
#                 "y": 317,
#                 "width": 170,
#                 "height": 30
#             }
#         },
#         {
#             "name": "See All Buying Options",
#             "type": "button",
#             "bbox": {
#                 "x": 840,
#                 "y": 361,
#                 "width": 190,
#                 "height": 30
#             }
#         },
#         {
#             "name": "Add to List",
#             "type": "button",
#             "bbox": {
#                 "x": 840,
#                 "y": 405,
#                 "width": 120,
#                 "height": 30
#             }
#         },
#         {
#             "name": "Learn more",
#             "type": "button",
#             "bbox": {
#                 "x": 840,
#                 "y": 202,
#                 "width": 100,
#                 "height": 16
#             }
#         },
#         {
#             "name": "Search this page",
#             "type": "button",
#             "bbox": {
#                 "x": 550,
#                 "y": 370,
#                 "width": 110,
#                 "height": 16
#             }
#         },
#         {
#             "name": "See more",
#             "type": "button",
#             "bbox": {
#                 "x": 530,
#                 "y": 940,
#                 "width": 70,
#                 "height": 16
#             }
#         },
#         {
#             "name": "All",
#             "type": "dropdown",
#             "bbox": {
#                 "x": 48,
#                 "y": 48,
#                 "width": 48,
#                 "height": 24
#             }
#         },
#         {
#             "name": "laptop stand",
#             "type": "text field",
#             "bbox": {
#                 "x": 224,
#                 "y": 45,
#                 "width": 120,
#                 "height": 24
#             }
#         },
#         {
#             "name": "Account & Lists",
#             "type": "dropdown",
#             "bbox": {
#                 "x": 775,
#                 "y": 18,
#                 "width": 110,
#                 "height": 24
#             }
#         }
#     ],
#     "add-to-cart.png": [
#         {
#             "name": "Apply 10%",
#             "type": "checkbox",
#             "bbox": {
#                 "x": 808,
#                 "y": 343,
#                 "width": 88,
#                 "height": 20
#             }
#         },
#         {
#             "name": "Add to Cart",
#             "type": "button",
#             "bbox": {
#                 "x": 928,
#                 "y": 339,
#                 "width": 94,
#                 "height": 28
#             }
#         },
#         {
#             "name": "See more",
#             "type": "button",
#             "bbox": {
#                 "x": 511,
#                 "y": 960,
#                 "width": 70,
#                 "height": 16
#             }
#         }
#     ],
#     "confirmation.png": [
#         {
#             "name": "Search Amazon",
#             "type": "text field",
#             "bounding_box": {
#                 "x": 186,
#                 "y": 18,
#                 "width": 150,
#                 "height": 26
#             }
#         },
#         {
#             "name": "All",
#             "type": "dropdown",
#             "bounding_box": {
#                 "x": 74,
#                 "y": 18,
#                 "width": 42,
#                 "height": 26
#             }
#         },
#         {
#             "name": "Proceed to checkout (6 items)",
#             "type": "button",
#             "bounding_box": {
#                 "x": 746,
#                 "y": 193,
#                 "width": 200,
#                 "height": 28
#             }
#         },
#         {
#             "name": "Go to Cart",
#             "type": "button",
#             "bounding_box": {
#                 "x": 786,
#                 "y": 227,
#                 "width": 120,
#                 "height": 22
#             }
#         },
#         {
#             "name": "Go to Cart",
#             "type": "button",
#             "bounding_box": {
#                 "x": 930,
#                 "y": 46,
#                 "width": 70,
#                 "height": 22
#             }
#         },
#         {
#             "name": null,
#             "type": "button",
#             "bounding_box": {
#                 "x": 605,
#                 "y": 575,
#                 "width": 26,
#                 "height": 26
#             }
#         },
#         {
#             "name": null,
#             "type": "button",
#             "bounding_box": {
#                 "x": 880,
#                 "y": 575,
#                 "width": 26,
#                 "height": 26
#             }
#         },
#         {
#             "name": null,
#             "type": "dropdown",
#             "bounding_box": {
#                 "x": 932,
#                 "y": 295,
#                 "width": 22,
#                 "height": 22
#             }
#         },
#         {
#             "name": null,
#             "type": "dropdown",
#             "bounding_box": {
#                 "x": 932,
#                 "y": 494,
#                 "width": 22,
#                 "height": 22
#             }
#         },
#         {
#             "name": null,
#             "type": "dropdown",
#             "bounding_box": {
#                 "x": 932,
#                 "y": 690,
#                 "width": 22,
#                 "height": 22
#             }
#         },
#         {
#             "name": null,
#             "type": "dropdown",
#             "bounding_box": {
#                 "x": 932,
#                 "y": 890,
#                 "width": 22,
#                 "height": 22
#             }
#         }
#     ]
# }

# %%
import os
import json
from PIL import Image

def crop_ui_elements(image_path, ui_coordinates):
    """Crop UI elements from a screenshot based on bounding box coordinates.

    Args:
        image_path (str): Path to the image to crop.
        ui_coordinates (list): List of UI elements with bounding box coordinates.

    Returns:
        dict: Dictionary of cropped images with UI element names as keys.
    """
    img = Image.open(image_path).convert("RGB")  # Ensure RGB mode for quality
    width, height = img.size  # Get actual image size
    cropped_images = {}

    for i, element in enumerate(ui_coordinates):
        # Handle different bounding box key formats
        bbox_key = "bounding_box" if "bounding_box" in element else "bbox" if "bbox" in element else None
        if not bbox_key:
            print(f"Skipping element {i} in {image_path}: No bounding box found")
            continue  # Skip if no bounding box exists

        # Extract bounding box coordinates safely
        try:
            x = element[bbox_key]['x']
            y = element[bbox_key]['y']
            w = element[bbox_key]['width']
            h = element[bbox_key]['height']

            # 🔹 Normalize coordinates if needed
            if 0 < x < 1 and 0 < y < 1 and w <= 1 and h <= 1:
                x = int(x * width)
                y = int(y * height)
                w = int(w * width)
                h = int(h * height)

            # Ensure coordinates are within image bounds
            x, y = max(0, x), max(0, y)
            w, h = min(width - x, w), min(height - y, h)

            # Define the cropping box (left, upper, right, lower)
            crop_box = (x, y, x + w, y + h)
            cropped_img = img.crop(crop_box)  # Crop the image

            # Get element name, fallback to generic name if missing
            # element_name = element.get("name", f"Element_{i}").replace(" ", "_")

            # Store cropped image
            cropped_images[element_name] = cropped_img

        except KeyError as e:
            print(f"Error: Missing key {e} in element {i} of {image_path}")

    return cropped_images

# Load UI coordinates from JSON file
with open("ui_coordinates.json", "r") as file:
    ui_coordinates = json.load(file)

# List of images to process
image_paths = [
    "amazon-home.png",
    "amazon-search.png",
    "product-detail.png",
    "add-to-cart.png",
    "confirmation.png"
]

# Output folder for cropped images
output_dir = "cropped_images"
os.makedirs(output_dir, exist_ok=True)

# Process and save cropped UI elements
cropped_elements_per_image = {}

for image in image_paths:
    if image in ui_coordinates:  # Ensure UI coordinates exist for the image
        cropped_elements = crop_ui_elements(image, ui_coordinates[image])
        cropped_elements_per_image[image] = cropped_elements

        # Save cropped images
        for element_name, cropped_img in cropped_elements.items():
            output_path = os.path.join(output_dir, f"{image}_{element_name}.png")
            cropped_img.save(output_path, quality=100)  # Ensure max quality
            print(f"Saved: {output_path}")

print("\nBatch processing complete. Cropped UI elements saved.")
# Out:
# Saved: cropped_images/amazon-home.png_See_more.png
# Saved: cropped_images/amazon-search.png_See_more.png
# Saved: cropped_images/product-detail.png_See_more.png
# Saved: cropped_images/add-to-cart.png_See_more.png
# Saved: cropped_images/confirmation.png_See_more.png
#
# ✅ Batch processing complete. Cropped UI elements saved.

# %%
import shutil
from google.colab import files

folder_path = "cropped_images"  # Change this to your folder name
zip_filename = folder_path + ".zip"

# Zip the folder
shutil.make_archive(folder_path, 'zip', folder_path)

# Download the zip file
files.download(zip_filename)

# %%
import os
from PIL import Image, ImageDraw, ImageFont

def highlight_ui_elements(image_path, ui_coordinates, output_path=None):
    """
    Highlight UI elements in the screenshot by drawing bounding boxes.

    Args:
        - image_path (str): Path to the original image.
        - ui_coordinates (list): List of UI elements with bounding box coordinates.
        - output_path (str, optional): Path to save the output image with highlighted elements.

    Returns:
        - Image object with highlighted elements.
    """
    # Load the image
    img = Image.open(image_path).convert("RGB")
    draw = ImageDraw.Draw(img)
    width, height  = img.size

    # Loop through each UI element and draw bounding boxes
    for i, element in enumerate(ui_coordinates):
        # Handle different bounding box key formats
        bbox_key = "bounding_box" if "bounding_box" in element else "bbox" if "bbox" in element else None
        if not bbox_key:
            print(f"Skipping element {i} in {image_path}: No bounding box found")
            continue  # Skip if no bounding box exists

    try:
            x = element[bbox_key]['x']
            y = element[bbox_key]['y']
            w = element[bbox_key]['width']
            h = element[bbox_key]['height']

            # Normalize coordinates if needed
            if 0 < x < 1 and 0 < y < 1 and w <= 1 and h <= 1:
                x = int(x * width)
                y = int(y * height)
                w = int(w * width)
                h = int(h * height)

            # Ensure coordinates are within image bounds
            x, y = max(0, x), max(0, y)
            w, h = min(width - x, w), min(height - y, h)

            # Draw the bounding box (left, upper, right, lower)
            draw.rectangle([x, y, x + w, y + h], outline="red", width=3)  # Red color for highligh
    except KeyError as e:
            print(f"Error: Missing key {e} in element {i} of {image_path}")
    img.save(output_path, quality=100)  # Save with maximum quality
    print(f"Highlighted image saved: {output_path}")

# Load UI coordinates from JSON file
with open("ui_coordinates.json", "r") as file:
    ui_coordinates = json.load(file)

# List of images to process
image_paths = [
    "amazon-home.png",
    "amazon-search.png",
    "product-detail.png",
    "add-to-cart.png",
    "confirmation.png"
]
# Output folder for highlighted images
output_dir = "highlighted_images"
os.makedirs(output_dir, exist_ok=True)

# Process and save highlighted UI elements
for image in image_paths:
    if image in ui_coordinates:  # Ensure UI coordinates exist for the image
        # Set output path for the highlighted image
        output_path = os.path.join(output_dir, f"highlighted_{image}")

        # Highlight UI elements and save the image
        highlight_ui_elements(image, ui_coordinates[image], output_path)

print("\nHighlighting complete. Images with highlighted UI elements saved.")
